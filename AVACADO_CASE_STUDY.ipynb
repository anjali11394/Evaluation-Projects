# %%
#importing basic libraries

import numpy as np
import pandas as pd

# %%
df=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/Data-Science-ML-Capstone-Projects/master/avocado.csv.zip')

# %%
df.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# ...

# %%
#checking the shape of the dataset

df.shape
# Out:
# (18249, 14)

# %%
#checking the null values and data types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    18249 non-null  int64
#  1   Date          18249 non-null  object
#  2   AveragePrice  18249 non-null  float64
#  3   Total Volume  18249 non-null  float64
#  4   4046          18249 non-null  float64
#  5   4225          18249 non-null  float64
#  6   4770          18249 non-null  float64
#  7   Total Bags    18249 non-null  float64
#  8   Small Bags    18249 non-null  float64
#  9   Large Bags    18249 non-null  float64
#  10  XLarge Bags   18249 non-null  float64
#  11  type          18249 non-null  object
#  12  year          18249 non-null  int64
#  13  region        18249 non-null  object
# dtypes: float64(9), int64(2), object(3)
# memory usage: 1.9+ MB

# %%
#statistics of data

df.describe()
# Out:
#          Unnamed: 0  AveragePrice  Total Volume          4046          4225  \
# count  18249.000000  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04
# mean      24.232232      1.405978  8.506440e+05  2.930084e+05  2.951546e+05
# std       15.481045      0.402677  3.453545e+06  1.264989e+06  1.204120e+06
# min        0.000000      0.440000  8.456000e+01  0.000000e+00  0.000000e+00
# 25%       10.000000      1.100000  1.083858e+04  8.540700e+02  3.008780e+03
# 50%       24.000000      1.370000  1.073768e+05  8.645300e+03  2.906102e+04
# 75%       38.000000      1.660000  4.329623e+05  1.110202e+05  1.502069e+05
# max       52.000000      3.250000  6.250565e+07  2.274362e+07  2.047057e+07
#
#                4770    Total Bags    Small Bags    Large Bags    XLarge Bags  \
# count  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000
# mean   2.283974e+04  2.396392e+05  1.821947e+05  5.433809e+04    3106.426507
# ...

# %%
df=df.drop(['Unnamed: 0'],axis=1)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(20,8))
sns.countplot(data=df, x="type",);
df.type.value_counts()
# Out:
# conventional    9126
# organic         9123
# Name: type, dtype: int64

# %% [markdown]
# Both the catgeories are almost equal.

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(10,40))
sns.countplot(data=df, y="region",);
df.region.value_counts()
# Out:
# Albany                 338
# Sacramento             338
# Northeast              338
# NorthernNewEngland     338
# Orlando                338
# Philadelphia           338
# PhoenixTucson          338
# Pittsburgh             338
# Plains                 338
# Portland               338
# RaleighGreensboro      338
# RichmondNorfolk        338
# Roanoke                338
# SanDiego               338
# Atlanta                338
# SanFrancisco           338
# Seattle                338
# SouthCarolina          338
# SouthCentral           338
# Southeast              338
# Spokane                338
# StLouis                338
# Syracuse               338
# Tampa                  338
# TotalUS                338
# West                   338
# NewYork                338
# NewOrleansMobile       338
# Nashville              338
# Midsouth               338
# BaltimoreWashington    338
# Boise                  338
# Boston                 338
# BuffaloRochester       338
# ...

# %%
df.region.unique()
# Out:
# array(['Albany', 'Atlanta', 'BaltimoreWashington', 'Boise', 'Boston',
#        'BuffaloRochester', 'California', 'Charlotte', 'Chicago',
#        'CincinnatiDayton', 'Columbus', 'DallasFtWorth', 'Denver',
#        'Detroit', 'GrandRapids', 'GreatLakes', 'HarrisburgScranton',
#        'HartfordSpringfield', 'Houston', 'Indianapolis', 'Jacksonville',
#        'LasVegas', 'LosAngeles', 'Louisville', 'MiamiFtLauderdale',
#        'Midsouth', 'Nashville', 'NewOrleansMobile', 'NewYork',
#        'Northeast', 'NorthernNewEngland', 'Orlando', 'Philadelphia',
#        'PhoenixTucson', 'Pittsburgh', 'Plains', 'Portland',
#        'RaleighGreensboro', 'RichmondNorfolk', 'Roanoke', 'Sacramento',
#        'SanDiego', 'SanFrancisco', 'Seattle', 'SouthCarolina',
#        'SouthCentral', 'Southeast', 'Spokane', 'StLouis', 'Syracuse',
#        'Tampa', 'TotalUS', 'West', 'WestTexNewMexico'], dtype=object)

# %%
len(df.region.unique())
# Out:
# 54

# %% [markdown]
# There are 54 regions from where observation is done with eqaul distribution.

# %%
#realtion with target variable

plt.figure(figsize=(30,10))
sns.set_style('whitegrid')
sns.scatterplot(x='AveragePrice',y='Total Volume',data=df);
plt.xlabel('AveragePrice')
plt.ylabel('Total Volume')
plt.title('RELATIONSHIP B/W FEATURE AND VARIABLE')
# Out:
# Text(0.5, 1.0, 'RELATIONSHIP B/W FEATURE AND VARIABLE')

# %%
#relation with target variable

plt.figure(figsize=(30,10))
sns.set_style('whitegrid')
sns.scatterplot(x='AveragePrice',y='4046',data=df,color='red');
sns.scatterplot(x='AveragePrice',y='4225',data=df,color='blue');
sns.scatterplot(x='AveragePrice',y='4770',data=df,color='green');
plt.xlabel('AveragePrice')
plt.ylabel('4046/4225/4770')
plt.title('RELATIONSHIP B/W FEATURE AND VARIABLE');

# %%
#relation with target variable

plt.figure(figsize=(30,10))
sns.set_style('whitegrid')
sns.scatterplot(x='AveragePrice',y='Small Bags',data=df,color='orange');
sns.scatterplot(x='AveragePrice',y='Large Bags',data=df,color='purple');
sns.scatterplot(x='AveragePrice',y='XLarge Bags',data=df,color='green');
plt.xlabel('AveragePrice')
plt.ylabel('Small Bags/Large Bags/XLarge Bags')
plt.title('RELATIONSHIP B/W FEATURE AND VARIABLE');

# %%
#relation with target variable

plt.figure(figsize=(30,10))
sns.set_style('whitegrid')
sns.scatterplot(x='Small Bags',y='AveragePrice',data=df,color='orange');
sns.scatterplot(x='Large Bags',y='AveragePrice',data=df,color='purple');
sns.scatterplot(x='XLarge Bags',y='AveragePrice',data=df,color='green');
plt.xlabel('AveragePrice')
plt.ylabel('Small Bags/Large Bags/XLarge Bags')
plt.title('RELATIONSHIP B/W FEATURE AND VARIABLE');

# %%
#realtion with target variable

plt.figure(figsize=(30,10))
sns.set_style('whitegrid')
sns.scatterplot(x='AveragePrice',y='Total Bags',data=df,color='red');
plt.xlabel('AveragePrice')
plt.ylabel('Total Bags')
plt.title('RELATIONSHIP B/W FEATURE AND VARIABLE')
# Out:
# Text(0.5, 1.0, 'RELATIONSHIP B/W FEATURE AND VARIABLE')

# %%
#realtion with target variable

plt.figure(figsize=(30,10))
sns.set_style('whitegrid')
sns.scatterplot(x='AveragePrice',y='type',data=df,color='purple');
plt.xlabel('AveragePrice')
plt.ylabel('type')
plt.title('RELATIONSHIP B/W FEATURE AND VARIABLE')
# Out:
# Text(0.5, 1.0, 'RELATIONSHIP B/W FEATURE AND VARIABLE')

# %%
#realtion with target variable

plt.figure(figsize=(30,40))
sns.set_style('whitegrid')
sns.scatterplot(x='AveragePrice',y='region',data=df,color='teal');
plt.xlabel('AveragePrice')
plt.ylabel('type')
plt.title('RELATIONSHIP B/W FEATURE AND VARIABLE')
# Out:
# Text(0.5, 1.0, 'RELATIONSHIP B/W FEATURE AND VARIABLE')

# %%
#realtion with target variable

plt.figure(figsize=(30,10))
sns.set_style('whitegrid')
sns.relplot(x='AveragePrice',y='year',data=df,color='teal');
plt.xlabel('AveragePrice')
plt.ylabel('year')
plt.title('RELATIONSHIP B/W FEATURE AND VARIABLE')
# Out:
# Text(0.5, 1.0, 'RELATIONSHIP B/W FEATURE AND VARIABLE')

# %%
#data distribution of numerical data

plt.figure(figsize=(40,20))
sns.set()

plotnumber=1

for num in df[['AveragePrice', 'Total Volume', '4046', '4225', '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags',  'year']]:
              if plotnumber <=10:
                ax=plt.subplot(5,2,plotnumber)
                sns.distplot(df[num]) 
                plotnumber += 1
              
              


plt.show()

# %%
df['XLarge Bags'].unique()
# Out:
# array([  0.  ,  33.33, 104.17, ..., 228.27,  12.12,  24.18])

# %%
df['XLarge Bags'].value_counts()
# Out:
# 0.00       12048
# 3.33          29
# 6.67          16
# 1.11          15
# 5.00          12
#            ...
# 3018.05        1
# 2739.44        1
# 9301.67        1
# 8640.00        1
# 24.18          1
# Name: XLarge Bags, Length: 5588, dtype: int64

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (18249, 13)

# %%
#data distribution of numerical data

plt.figure(figsize=(40,20))
sns.set()

plotnumber=1

for num in df[['AveragePrice', 'Total Volume', '4046', '4225', '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags',  'year']]:
              if plotnumber <=10:
                ax=plt.subplot(5,2,plotnumber)
                sns.boxplot(df[num]) 
                plotnumber += 1
              
              


plt.show()

# %%
#importing zscore to remove outliers

from scipy.stats import zscore

# %%
z_score=zscore(df[['AveragePrice', 'Total Volume', '4046', '4225', '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags']])

# %%
abs_z_score=np.abs(z_score)

# %%
filtering_entry=(abs_z_score < 3).all(axis=1)

# %%
df=df[filtering_entry]

# %%
#statistics of data after removing outliers

df.describe()
# Out:
#        AveragePrice  Total Volume          4046          4225           4770  \
# count  17651.000000  1.765100e+04  1.765100e+04  1.765100e+04   17651.000000
# mean       1.405363  4.612232e+05  1.546436e+05  1.656009e+05   11160.558411
# std        0.385793  1.012727e+06  4.395780e+05  3.991041e+05   34488.049314
# min        0.440000  8.456000e+01  0.000000e+00  0.000000e+00       0.000000
# 25%        1.110000  1.056651e+04  8.219250e+02  2.889740e+03       0.000000
# 50%        1.380000  1.002071e+05  7.785240e+03  2.670378e+04     163.960000
# 75%        1.660000  3.911843e+05  9.840492e+04  1.288019e+05    5284.600000
# max        2.610000  8.362504e+06  4.085859e+06  3.894802e+06  344488.510000
#
#          Total Bags    Small Bags     Large Bags   XLarge Bags          year
# count  1.765100e+04  1.765100e+04   17651.000000  17651.000000  17651.000000
# mean   1.298160e+05  1.006283e+05   27830.325482   1357.351712   2016.137669
# ...

# %%
df.shape
# Out:
# (17651, 13)

# %%
df=df.drop(['Date','region'],axis=1)

# %%
cat_data=df.select_dtypes(include=['object'])

# %%
cat_data
# Out:
#                type
# 0      conventional
# 1      conventional
# 2      conventional
# 3      conventional
# 4      conventional
# ...             ...
# 18244       organic
# 18245       organic
# 18246       organic
# 18247       organic
# 18248       organic
#
# [17651 rows x 1 columns]

# %%
#separating numerical data

num_data=df.select_dtypes(include=['float64','int64'])

# %%
num_data.head()
# Out:
#    AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0          1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1          1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2          0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3          1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4          1.28      51039.60   941.48   43838.39   75.78     6183.95
#
#    Small Bags  Large Bags  XLarge Bags  year
# 0     8603.62       93.25          0.0  2015
# 1     9408.07       97.49          0.0  2015
# 2     8042.21      103.14          0.0  2015
# 3     5677.40      133.76          0.0  2015
# 4     5986.26      197.69          0.0  2015

# %%
cat_df=pd.get_dummies(cat_data,drop_first=True)

# %%
cat_df
# Out:
#        type_organic
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0
# ...             ...
# 18244             1
# 18245             1
# 18246             1
# 18247             1
# 18248             1
#
# [17651 rows x 1 columns]

# %%
df1=pd.concat([num_data,cat_df],axis=1)

# %%
df1.head()
# Out:
#    AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0          1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1          1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2          0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3          1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4          1.28      51039.60   941.48   43838.39   75.78     6183.95
#
#    Small Bags  Large Bags  XLarge Bags  year  type_organic
# 0     8603.62       93.25          0.0  2015             0
# 1     9408.07       97.49          0.0  2015             0
# 2     8042.21      103.14          0.0  2015             0
# 3     5677.40      133.76          0.0  2015             0
# 4     5986.26      197.69          0.0  2015             0

# %%
df1.corr()
# Out:
#               AveragePrice  Total Volume      4046      4225      4770  \
# AveragePrice      1.000000     -0.332056 -0.333577 -0.243988 -0.243465
# Total Volume     -0.332056      1.000000  0.876307  0.871592  0.647518
# 4046             -0.333577      0.876307  1.000000  0.565118  0.492127
# 4225             -0.243988      0.871592  0.565118  1.000000  0.620221
# 4770             -0.243465      0.647518  0.492127  0.620221  1.000000
# Total Bags       -0.297323      0.912184  0.727981  0.757786  0.557980
# Small Bags       -0.275771      0.905648  0.706800  0.778761  0.571512
# Large Bags       -0.270915      0.640642  0.561060  0.451711  0.323747
# XLarge Bags      -0.152669      0.513741  0.415432  0.392030  0.495976
# year              0.091704     -0.004866 -0.034636 -0.040234 -0.082054
# type_organic      0.613150     -0.415476 -0.341376 -0.383138 -0.321809
#
#               Total Bags  Small Bags  Large Bags  XLarge Bags      year  \
# ...

# %%
plt.figure(figsize=(50,30))
sns.heatmap(df1.corr(),annot=True)

# %%
from sklearn.feature_selection import SelectPercentile, chi2

# %%
X=df1.drop(['AveragePrice'],axis=1)
y=df1['AveragePrice']

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()
X_scaler=scaler.fit_transform(X)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
import xgboost as xgb

from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.metrics import  mean_squared_error,mean_absolute_error
from sklearn.linear_model import Lasso, Ridge, LassoCV, RidgeCV
lr=LinearRegression()
rf=RandomForestRegressor()
dt=DecisionTreeRegressor()

# %%
for i in range(0,1000):
  x_train,x_test,y_train,y_test=train_test_split(X_scaler,y,test_size=0.20,random_state=i)
  lr.fit(x_train,y_train)
  pred_train=lr.predict(x_train)
  pred_test=lr.predict(x_test)
  if round(r2_score(y_train,pred_train)*100,1)==round(r2_score(y_test,pred_test)*100,1):
    print('At random state',i,'the model performs well')
    print('At random state',i)
    print('Training accuracy of data is :-',r2_score(y_train,pred_train)*100)
    print('Testing accuracy of data is :-',r2_score(y_test,pred_test)*100)
    print('\n')
# Out:
# At random state 17 the model performs well
# At random state 17
# Training accuracy of data is :- 41.22866603257683
# Testing accuracy of data is :- 41.192073210395904
#
#
# At random state 63 the model performs well
# At random state 63
# Training accuracy of data is :- 41.236149306453676
# Testing accuracy of data is :- 41.174711586732826
#
#
# At random state 93 the model performs well
# At random state 93
# Training accuracy of data is :- 41.22145368504098
# Testing accuracy of data is :- 41.237660558583485
#
#
# At random state 132 the model performs well
# At random state 132
# Training accuracy of data is :- 41.2285536291103
# Testing accuracy of data is :- 41.19162327380058
#
#
# At random state 174 the model performs well
# At random state 174
# Training accuracy of data is :- 41.22530857398496
# Testing accuracy of data is :- 41.21648874529199
#
#
# At random state 201 the model performs well
# At random state 201
# Training accuracy of data is :- 41.21473084799978
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(X_scaler,y,test_size=0.2,random_state=93)

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
pred_test=lr.predict(x_test)

# %%
print(r2_score(y_test,pred_test))
# Out:
# 0.4123766055858349

# %%
y_pred=lr.predict(x_test)

# %%
#DATA REPERESENTATION

plt.scatter(y_test,y_pred)
plt.xlabel('Actual average cost')
plt.ylabel('Predicted average cost')
plt.title('ACTUAL V/S PREDICTED')
plt.show()

# %%
rf.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
rf_train_pred=rf.predict(x_train)

# %%
rf_test_pred=rf.predict(x_test)

# %%
print(r2_score(y_test,rf_test_pred))
# Out:
# 0.8081687694979155

# %%
rf_y_pred=rf.predict(x_test)

# %%
plt.scatter(y_test,rf_y_pred)
plt.xlabel('Actual average cost')
plt.ylabel('Predicted average cost')
plt.title('ACTUAL V/S PREDICTED')
plt.show()

# %%
dt.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
dt_train_pred=dt.predict(x_train)

# %%
dt_test_pred=dt.predict(x_test)

# %%
print(r2_score(y_test,dt_test_pred))
# Out:
# 0.6181751350959018

# %%
dt_y_pred=dt.predict(x_test)

# %%
plt.scatter(y_test,dt_y_pred)
plt.xlabel('Actual average cost')
plt.ylabel('Predicted average cost')
plt.title('ACTUAL V/S PREDICTED')
plt.show()

# %%
xgb=xgb.XGBRegressor()

# %%
xgb.fit(x_train,y_train)
# Out:
# [04:51:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBRegressor()

# %%
xgb_train_pred=xgb.predict(x_train)

# %%
xgb_test_pred=xgb.predict(x_test)

# %%
print(r2_score(y_test,xgb_test_pred))
# Out:
# 0.642032681745643

# %%
xgb_y_pred=xgb.predict(x_test)

# %%
plt.scatter(y_test,xgb_y_pred)
plt.xlabel('Actual average cost')
plt.ylabel('Predicted average cost')
plt.title('ACTUAL V/S PREDICTED')
plt.show()

# %%
plt.figure(figsize=(30,15))
plt.scatter(y_test,xgb_y_pred,color='yellow',marker=r'$\alpha$')
plt.scatter(y_test,dt_y_pred,color='teal',marker='o')
plt.scatter(y_test,rf_y_pred,color='black',marker='>')
plt.scatter(y_test,y_pred,color='pink')
plt.xlabel('Actual average cost')
plt.ylabel('Predicted average cost')
plt.title('ACTUAL V/S PREDICTED')
plt.show()

# %%
from sklearn.model_selection import  GridSearchCV

# %%
param_grid = { 'criterion' : ['mse','mae'],
            "n_estimators"      : [10,20,30],
            "max_features"      : ["auto", "sqrt", "log2"],
            "min_samples_split" : [2,4,8],
            "bootstrap": [True, False],
            }

# %%
clf=GridSearchCV(rf,param_grid)

# %%
clf.fit(x_train,y_train)
# Out:
# GridSearchCV(estimator=RandomForestRegressor(),
#              param_grid={'bootstrap': [True, False],
#                          'criterion': ['mse', 'mae'],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'min_samples_split': [2, 4, 8],
#                          'n_estimators': [10, 20, 30]})

# %%
print(clf.best_params_)
# Out:
# {'bootstrap': False, 'criterion': 'mae', 'max_features': 'log2', 'min_samples_split': 2, 'n_estimators': 30}

# %%
rf_new=RandomForestRegressor(bootstrap= False, criterion= 'mse', max_features= 'log2', min_samples_split=4, n_estimators= 30)

# %%
rf_new.fit(x_train,y_train)
# Out:
# RandomForestRegressor(bootstrap=False, criterion='mse', max_features='log2',
#                       min_samples_split=4, n_estimators=30)

# %%
rf_new_train_pred=rf.predict(x_train)

# %%
rf_new_test_pred=rf.predict(x_test)

# %%
print(r2_score(y_test,rf_new_test_pred))
# Out:
# 0.8081687694979155

# %%
import joblib

# %%
joblib.dump(rf,'avacado_cost.obj')
# Out:
# ['avacado_cost.obj']

# %%
model=joblib.load('avacado_cost.obj')

# %%
result=model.predict(x_test)

# %%
r2_score(y_test,result)
# Out:
# 0.8081687694979155

# %%
predicted_values=pd.DataFrame({'Actual':y_test,'Predicted':result})

# %%
predicted_values
# Out:
#        Actual  Predicted
# 15470    0.65     0.6896
# 4246     0.58     0.8181
# 15280    1.73     1.6206
# 14025    2.33     2.1622
# 9324     1.50     1.5815
# ...       ...        ...
# 7111     1.68     1.5766
# 5796     1.54     1.4314
# 3516     0.86     1.0042
# 15781    1.65     1.5128
# 2441     1.19     1.0895
#
# [3531 rows x 2 columns]

# %%
X=df1.drop(['type_organic'],axis=1)
y=df1['type_organic']

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()
x_scaler=scaler.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV


lr=LogisticRegression()
dt=DecisionTreeClassifier()
rf=RandomForestClassifier()
knn=KNeighborsClassifier()

# %%
for i in range(0,1000):
  x_train,x_test,y_train,y_test=train_test_split(x_scaler,y,test_size=0.20,random_state=i)
  lr.fit(x_train,y_train)
  pred_train=lr.predict(x_train)
  pred_test=lr.predict(x_test)
  if round(accuracy_score(y_train,pred_train)*100,1)==round(accuracy_score(y_test,pred_test)*100,1):
    print('At random state',i,'the model performs well')
    print('At random state',i)
    print('Training accuracy of data is :-',accuracy_score(y_train,pred_train)*100)
    print('Testing accuracy of data is :-',accuracy_score(y_test,pred_test)*100)
    print('\n')
# Out:
# At random state 9 the model performs well
# At random state 9
# Training accuracy of data is :- 93.56940509915013
# Testing accuracy of data is :- 93.62786745964317
#
#
# At random state 10 the model performs well
# At random state 10
# Training accuracy of data is :- 93.51274787535411
# Testing accuracy of data is :- 93.45794392523365
#
#
# At random state 14 the model performs well
# At random state 14
# Training accuracy of data is :- 93.48441926345609
# Testing accuracy of data is :- 93.54290569243841
#
#
# At random state 15 the model performs well
# At random state 15
# Training accuracy of data is :- 93.51274787535411
# Testing accuracy of data is :- 93.51458510337015
#
#
# At random state 37 the model performs well
# At random state 37
# Training accuracy of data is :- 93.48441926345609
# Testing accuracy of data is :- 93.51458510337015
#
#
# At random state 41 the model performs well
# At random state 41
# Training accuracy of data is :- 93.57648725212464
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(x_scaler,y,test_size=0.20,random_state=713)

# %%
print(classification_report(y_test,pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.50      0.47      0.48      1752
#            1       0.51      0.54      0.53      1779
#
#     accuracy                           0.51      3531
#    macro avg       0.50      0.50      0.50      3531
# weighted avg       0.50      0.51      0.50      3531

# %%
pred_lr=lr.predict(x_test)

lss=accuracy_score(y_test,pred_lr)
for j in range(2,10):
  lsscore=cross_val_score(lr,x_scaler,y,cv=j)
  lsc=lsscore.mean()
  print('At cv:-',j)
  print('cross validation score is :-',lsc*100)
  print('accuracy score is:-',lss*100)
  print('\n')
# Out:
# At cv:- 2
# cross validation score is :- 91.00313970634019
# accuracy score is:- 93.51458510337015
#
#
# At cv:- 3
# cross validation score is :- 92.45927815377426
# accuracy score is:- 93.51458510337015
#
#
# At cv:- 4
# cross validation score is :- 93.04858805445626
# accuracy score is:- 93.51458510337015
#
#
# At cv:- 5
# cross validation score is :- 92.96905835244772
# accuracy score is:- 93.51458510337015
#
#
# At cv:- 6
# cross validation score is :- 92.93528447872745
# accuracy score is:- 93.51458510337015
#
#
# At cv:- 7
# cross validation score is :- 93.12186155608623
# accuracy score is:- 93.51458510337015
#
#
# At cv:- 8
# cross validation score is :- 92.91807397216718
# accuracy score is:- 93.51458510337015
#
#
# At cv:- 9
# cross validation score is :- 92.95762209615997
# accuracy score is:- 93.51458510337015

# %%
lsscore_selected=cross_val_score(lr,x_scaler,y,cv=7).mean()
print('The cv score is ',lsscore_selected*100, '\n the accuracy score is ',lss*100)
# Out:
# The cv score is  93.12186155608623
#  the accuracy score is  93.51458510337015

# %%
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
dt_train_pred=dt.predict(x_train)

# %%
dt_test_pred=dt.predict(x_test)

# %%
print(classification_report(y_test,dt_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      1752
#            1       0.99      0.99      0.99      1779
#
#     accuracy                           0.99      3531
#    macro avg       0.99      0.99      0.99      3531
# weighted avg       0.99      0.99      0.99      3531

# %%
pred_dt=dt.predict(x_test)

lss=accuracy_score(y_test,pred_dt)
for j in range(2,10):
  lsscore=cross_val_score(dt,x_scaler,y,cv=j)
  lsc=lsscore.mean()
  print('At cv:-',j)
  print('cross validation score is :-',lsc*100)
  print('accuracy score is:-',lss*100)
  print('\n')
# Out:
# At cv:- 2
# cross validation score is :- 93.99466487438286
# accuracy score is:- 98.69725290286038
#
#
# At cv:- 3
# cross validation score is :- 94.2834783528446
# accuracy score is:- 98.69725290286038
#
#
# At cv:- 4
# cross validation score is :- 95.1615552027421
# accuracy score is:- 98.69725290286038
#
#
# At cv:- 5
# cross validation score is :- 96.05683693518276
# accuracy score is:- 98.69725290286038
#
#
# At cv:- 6
# cross validation score is :- 95.94345953075334
# accuracy score is:- 98.69725290286038
#
#
# At cv:- 7
# cross validation score is :- 95.47887245270462
# accuracy score is:- 98.69725290286038
#
#
# At cv:- 8
# cross validation score is :- 95.80194025356558
# accuracy score is:- 98.69725290286038
#
#
# At cv:- 9
# cross validation score is :- 95.56943996099267
# accuracy score is:- 98.69725290286038

# %%
lsscore_selected=cross_val_score(dt,x_scaler,y,cv=5).mean()
print('The cv score is ',lsscore_selected*100, '\n the accuracy score is ',lss*100)
# Out:
# The cv score is  96.13614100283768
#  the accuracy score is  98.69725290286038

# %%
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
rf_train_pred=rf.predict(x_train)

# %%
rf_test_pred=rf.predict(x_test)

# %%
print(classification_report(y_test,rf_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      1752
#            1       1.00      0.99      0.99      1779
#
#     accuracy                           0.99      3531
#    macro avg       0.99      0.99      0.99      3531
# weighted avg       0.99      0.99      0.99      3531

# %%
pred_rf=rf.predict(x_test)

lss=accuracy_score(y_test,pred_rf)
for j in range(2,10):
  lsscore=cross_val_score(rf,x_scaler,y,cv=j)
  lsc=lsscore.mean()
  print('At cv:-',j)
  print('cross validation score is :-',lsc*100)
  print('accuracy score is:-',lss*100)
  print('\n')
# Out:
# At cv:- 2
# cross validation score is :- 96.59503758211156
# accuracy score is:- 99.43358821863495
#
#
# At cv:- 3
# cross validation score is :- 97.17857134740785
# accuracy score is:- 99.43358821863495
#
#
# At cv:- 4
# cross validation score is :- 97.14449514426079
# accuracy score is:- 99.43358821863495
#
#
# At cv:- 5
# cross validation score is :- 97.32017589251974
# accuracy score is:- 99.43358821863495
#
#
# At cv:- 6
# cross validation score is :- 97.39375672306937
# accuracy score is:- 99.43358821863495
#
#
# At cv:- 7
# cross validation score is :- 97.45038246083078
# accuracy score is:- 99.43358821863495
#
#
# At cv:- 8
# cross validation score is :- 97.51279977044933
# accuracy score is:- 99.43358821863495
#
#
# At cv:- 9
# cross validation score is :- 97.4220166736467
# accuracy score is:- 99.43358821863495

# %%
lsscore_selected=cross_val_score(rf,x_scaler,y,cv=9).mean()
print('The cv score is ',lsscore_selected*100, '\n the accuracy score is ',lss*100)
# Out:
# The cv score is  97.3766912143232
#  the accuracy score is  99.43358821863495

# %%
from sklearn.metrics import roc_curve, roc_auc_score
from sklearn.metrics import plot_roc_curve

# %%
disp=plot_roc_curve(dt,x_train,y_train)

plot_roc_curve(lr,x_train,y_train,ax=disp.ax_)

plot_roc_curve(rf,x_train,y_train,ax=disp.ax_)




plt.legend(prop={'size':10},loc='lower right')

plt.show()

# %%
disp=plot_roc_curve(dt,x_test,y_test)

plot_roc_curve(lr,x_test,y_test,ax=disp.ax_)

plot_roc_curve(rf,x_test,y_test,ax=disp.ax_)




plt.legend(prop={'size':10},loc='lower right')

plt.show()

# %%
import joblib

# %%
joblib.dump(rf,'avacado_category.obj')
# Out:
# ['avacado_category.obj']

# %%
model=joblib.load('avacado_category.obj')

# %%
result=model.predict(x_test)

# %%
accuracy_score(y_test,result)
# Out:
# 0.9943358821863495

# %%
predicted_values=pd.DataFrame({'Actual':y_test,'Predicted':result})

# %%
predicted_values
# Out:
#        Actual  Predicted
# 876         0          0
# 15658       1          1
# 8906        0          0
# 14665       1          1
# 8267        0          0
# ...       ...        ...
# 2096        0          0
# 7606        0          0
# 5133        0          0
# 14379       1          1
# 15061       1          1
#
# [3531 rows x 2 columns]
