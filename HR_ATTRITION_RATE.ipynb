# %%
#importing the basic libraries

import numpy as np
import pandas as pd

# %%
#reading the data

df=pd.read_csv("/content/ibm-hr-analytics-employee-attrition-performance (1) (1).zip")
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
#checking the shape of the dataset

df.shape
# Out:
# (1470, 35)

# %%
#checking the datatypes of the columns

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %% [markdown]
# There are no null values present in the dataset.
# Attrition (target variable ) is in object data type.
#
# Following columns are object datatype:
#
# 1.BusinessTravel
#
# 2.Department
#
# 3.Education field
#
# 4.Gender
#
# 5.Job role
#
# 6.Martial status
#
# 7.Over18
#
# 8.Overtime

# %%
#checking the null values of the dataset
df.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# #EDA

# %%
#CHECKING THE columns realtion with the target variable
#dividing the dataseet into features and target

X=df.drop(['Attrition'],axis=1)
y=df['Attrition']

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
plt.figure(figsize=(30,60))
plotnumber = 1

for column in X:
  if plotnumber <= 33:
    ax=plt.subplot(11,3,plotnumber)
    sns.stripplot(y,X[column])

    plotnumber +=1

plt.show()

# %% [markdown]
# Observations
# attrition: yes- they leave the company, no-they stay
#
# 1.People below the age of 40 have high chances of leaving the company and as the age goes up they are stable in the company.
#
# 2.Those who have education level below 4 ponts are likely to leave the company.
# It can be due to further education chances.
#
# 3.People belonging to marketing,life sciences and medical have high attrition level than other fields.
#
# 4.Those who have job level below 3 are likely to leave the company for better opportunities.
#
# 5.Those wh have income less than 12000 are likely to leave the company.
#
# 6.Those who are freshers or worked in less 2 companies have higher chances of leaving.
#
# 7.Those who have less than 18% salary hike are likely to leave the company.
#
# 8.Those who stocks in the company less than 1% or zero are likely to leave.
#
# 9.Those who have spent less than 5 years in the company have high chances to leave.
#
# 10.Those who have got less promotions are likely to leave.
#
# 11.Jobs in whicch travel is required frequently have high attrition.

# %%
#Checking the unique values in the columns

print('unique values of business travel',df['BusinessTravel'].unique())

print('-'*30)


print('unique values of department',df['Department'].unique())

print('-'*30)


print('unique values of EducationField',df['EducationField'].unique())

print('-'*30)

print('unique values of Gender ',df['Gender'].unique())

print('-'*30)

print('unique values of Jobrole ',df['JobRole'].unique())

print('-'*30)

print('unique values of Martial status ',df['MaritalStatus'].unique())

print('-'*30)

print('unique values of Over18  ',df['Over18'].unique())

print('-'*30)

print('unique values of OverTime  ',df['OverTime'].unique())

print('-'*30)
# Out:
# unique values of business travel ['Travel_Rarely' 'Travel_Frequently' 'Non-Travel']
# ------------------------------
# unique values of department ['Sales' 'Research & Development' 'Human Resources']
# ------------------------------
# unique values of EducationField ['Life Sciences' 'Other' 'Medical' 'Marketing' 'Technical Degree'
#  'Human Resources']
# ------------------------------
# unique values of Gender  ['Female' 'Male']
# ------------------------------
# unique values of Jobrole  ['Sales Executive' 'Research Scientist' 'Laboratory Technician'
#  'Manufacturing Director' 'Healthcare Representative' 'Manager'
#  'Sales Representative' 'Research Director' 'Human Resources']
# ------------------------------
# unique values of Martial status  ['Single' 'Married' 'Divorced']
# ------------------------------
# unique values of Over18   ['Y']
# ------------------------------
# unique values of OverTime   ['Yes' 'No']
# ------------------------------

# %%
#encoding object datatypes
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df2=le.fit_transform(df[['Department']])

# %%
df['Department']=df2
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0   41       Yes      Travel_Rarely       1102           2                 1
# 1   49        No  Travel_Frequently        279           1                 8
# 2   37       Yes      Travel_Rarely       1373           1                 2
# 3   33        No  Travel_Frequently       1392           1                 3
# 4   27        No      Travel_Rarely        591           1                 2
#
#    Education EducationField  EmployeeCount  EmployeeNumber  ...  \
# 0          2  Life Sciences              1               1  ...
# 1          1  Life Sciences              1               2  ...
# 2          2          Other              1               4  ...
# 3          4  Life Sciences              1               5  ...
# 4          1        Medical              1               7  ...
#
#    RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df2=le.fit_transform(df[['BusinessTravel']])


df['BusinessTravel']=df2
df.head()
# Out:
#    Age Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0   41       Yes               2       1102           2                 1
# 1   49        No               1        279           1                 8
# 2   37       Yes               2       1373           1                 2
# 3   33        No               1       1392           1                 3
# 4   27        No               2        591           1                 2
#
#    Education EducationField  EmployeeCount  EmployeeNumber  ...  \
# 0          2  Life Sciences              1               1  ...
# 1          1  Life Sciences              1               2  ...
# 2          2          Other              1               4  ...
# 3          4  Life Sciences              1               5  ...
# 4          1        Medical              1               7  ...
#
#    RelationshipSatisfaction StandardHours  StockOptionLevel  \
# 0                         1            80                 0
# ...

# %%
df2=le.fit_transform(df[['EducationField']])


df['EducationField']=df2
df.head()
# Out:
#    Age Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0   41       Yes               2       1102           2                 1
# 1   49        No               1        279           1                 8
# 2   37       Yes               2       1373           1                 2
# 3   33        No               1       1392           1                 3
# 4   27        No               2        591           1                 2
#
#    Education  EducationField  EmployeeCount  EmployeeNumber  ...  \
# 0          2               1              1               1  ...
# 1          1               1              1               2  ...
# 2          2               4              1               4  ...
# 3          4               1              1               5  ...
# 4          1               3              1               7  ...
#
#    RelationshipSatisfaction StandardHours  StockOptionLevel  \
# 0                         1            80                 0
# ...

# %%
df2=le.fit_transform(df[['Gender']])


df['Gender']=df2
df.head()
# Out:
#    Age Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0   41       Yes               2       1102           2                 1
# 1   49        No               1        279           1                 8
# 2   37       Yes               2       1373           1                 2
# 3   33        No               1       1392           1                 3
# 4   27        No               2        591           1                 2
#
#    Education  EducationField  EmployeeCount  EmployeeNumber  ...  \
# 0          2               1              1               1  ...
# 1          1               1              1               2  ...
# 2          2               4              1               4  ...
# 3          4               1              1               5  ...
# 4          1               3              1               7  ...
#
#    RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# 0                         1             80                 0
# ...

# %%
df2=le.fit_transform(df[['JobRole']])


df['JobRole']=df2
df.head()
# Out:
#    Age Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0   41       Yes               2       1102           2                 1
# 1   49        No               1        279           1                 8
# 2   37       Yes               2       1373           1                 2
# 3   33        No               1       1392           1                 3
# 4   27        No               2        591           1                 2
#
#    Education  EducationField  EmployeeCount  EmployeeNumber  ...  \
# 0          2               1              1               1  ...
# 1          1               1              1               2  ...
# 2          2               4              1               4  ...
# 3          4               1              1               5  ...
# 4          1               3              1               7  ...
#
#    RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# 0                         1             80                 0
# ...

# %%
df2=le.fit_transform(df[['MaritalStatus']])


df['MaritalStatus']=df2
df.head()
# Out:
#    Age Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0   41       Yes               2       1102           2                 1
# 1   49        No               1        279           1                 8
# 2   37       Yes               2       1373           1                 2
# 3   33        No               1       1392           1                 3
# 4   27        No               2        591           1                 2
#
#    Education  EducationField  EmployeeCount  EmployeeNumber  ...  \
# 0          2               1              1               1  ...
# 1          1               1              1               2  ...
# 2          2               4              1               4  ...
# 3          4               1              1               5  ...
# 4          1               3              1               7  ...
#
#    RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# 0                         1             80                 0
# ...

# %%
df2=le.fit_transform(df[['OverTime']])


df['OverTime']=df2
df.head()
# Out:
#    Age Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0   41       Yes               2       1102           2                 1
# 1   49        No               1        279           1                 8
# 2   37       Yes               2       1373           1                 2
# 3   33        No               1       1392           1                 3
# 4   27        No               2        591           1                 2
#
#    Education  EducationField  EmployeeCount  EmployeeNumber  ...  \
# 0          2               1              1               1  ...
# 1          1               1              1               2  ...
# 2          2               4              1               4  ...
# 3          4               1              1               5  ...
# 4          1               3              1               7  ...
#
#    RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# 0                         1             80                 0
# ...

# %%
df2=le.fit_transform(df[['Over18']])


df['Over18']=df2
df.head()
# Out:
#    Age Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0   41       Yes               2       1102           2                 1
# 1   49        No               1        279           1                 8
# 2   37       Yes               2       1373           1                 2
# 3   33        No               1       1392           1                 3
# 4   27        No               2        591           1                 2
#
#    Education  EducationField  EmployeeCount  EmployeeNumber  ...  \
# 0          2               1              1               1  ...
# 1          1               1              1               2  ...
# 2          2               4              1               4  ...
# 3          4               1              1               5  ...
# 4          1               3              1               7  ...
#
#    RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# 0                         1             80                 0
# ...

# %%
df.Attrition.replace({'Yes':0,'No':1},inplace=True)

# %%
df.head()
# Out:
#    Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0   41          0               2       1102           2                 1
# 1   49          1               1        279           1                 8
# 2   37          0               2       1373           1                 2
# 3   33          1               1       1392           1                 3
# 4   27          1               2        591           1                 2
#
#    Education  EducationField  EmployeeCount  EmployeeNumber  ...  \
# 0          2               1              1               1  ...
# 1          1               1              1               2  ...
# 2          2               4              1               4  ...
# 3          4               1              1               5  ...
# 4          1               3              1               7  ...
#
#    RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   int64
#  2   BusinessTravel            1470 non-null   int64
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   int64
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   int64
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   int64
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %% [markdown]
# Resizing the categorical data
#
# Undersampling

# %%
#class count

yes_attrition = df[df['Attrition'] == 0]
no_attrition = df[df['Attrition'] == 1]
print('Attrition 0(yes):', yes_attrition.shape)
print('Attrition 1(no):', no_attrition.shape)
# Out:
# Attrition 0(yes): (237, 35)
# Attrition 1(no): (1233, 35)

# %%
no_sample=no_attrition.sample(n=237)

# %%
no_sample.shape
# Out:
# (237, 35)

# %%
#concatenate the two data frames

new_df=pd.concat([no_sample,yes_attrition],axis=0)

# %%
new_df.head()
# Out:
#      Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 823   29          1               1        490           1                10
# 28    44          1               2        477           1                 7
# 464   37          1               2        799           1                 1
# 861   46          1               2       1402           2                 2
# 179   38          1               2       1380           1                 9
#
#      Education  EducationField  EmployeeCount  EmployeeNumber  ...  \
# 823          3               1              1            1143  ...
# 28           4               3              1              36  ...
# 464          3               5              1             623  ...
# 861          3               2              1            1204  ...
# 179          2               1              1             245  ...
#
#      RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# ...

# %%
df=new_df

# %%
df.describe().T
# Out:
#                           count          mean          std     min      25%  \
# Age                       474.0     35.362869     9.466262    18.0    29.00
# Attrition                 474.0      0.500000     0.500528     0.0     0.00
# BusinessTravel            474.0      1.605485     0.625778     0.0     1.00
# DailyRate                 474.0    775.390295   400.347119   103.0   441.50
# Department                474.0      1.303797     0.536714     0.0     1.00
# DistanceFromHome          474.0     10.147679     8.525755     1.0     3.00
# Education                 474.0      2.879747     1.024175     1.0     2.00
# EducationField            474.0      2.291139     1.374660     0.0     1.00
# EmployeeCount             474.0      1.000000     0.000000     1.0     1.00
# EmployeeNumber            474.0   1002.054852   577.464042     1.0   511.00
# EnvironmentSatisfaction   474.0      2.607595     1.155017     1.0     1.25
# ...

# %%
df.skew()
# Out:
# Age                         0.466657
# Attrition                   0.000000
# BusinessTravel             -1.340068
# DailyRate                   0.110894
# Department                  0.089669
# DistanceFromHome            0.785131
# Education                  -0.314601
# EducationField              0.553831
# EmployeeCount               0.000000
# EmployeeNumber              0.028488
# EnvironmentSatisfaction    -0.177087
# Gender                     -0.388012
# HourlyRate                  0.049355
# JobInvolvement             -0.532631
# JobLevel                    1.203830
# JobRole                    -0.406996
# JobSatisfaction            -0.176302
# MaritalStatus              -0.393876
# MonthlyIncome               1.578583
# MonthlyRate                 0.053914
# NumCompaniesWorked          0.968462
# Over18                      0.000000
# OverTime                    0.562706
# PercentSalaryHike           0.813688
# PerformanceRating           1.900857
# ...

# %%
plt.figure(figsize=(30,60))
plotnumber = 1

for column in df:
  if plotnumber <= 35:
    ax=plt.subplot(7,5,plotnumber)
    sns.boxplot(df[column])

    plotnumber +=1

plt.show()

# %% [markdown]
# #Removing outliers

# %%
df.shape
# Out:
# (474, 35)

# %%
#find the IQR(INTER QUANTILE RANGE) to identify outliers

#1st quantile
q1=df.quantile(0.25)

#3rd quantile
q3=df.quantile(0.75)

iqr=q3 - q1

# %%
joblevel_high=(q3.JobLevel + (1.5 *iqr.JobLevel))
joblevel_high

index=np.where(df['JobLevel'] >joblevel_high)
print(index)


df=df.drop(df.index[index])
print(df.shape)

df.reset_index()
# Out:
# (array([  3,  13,  16,  21,  23,  30,  32,  36,  51,  55,  56,  61,  63,
#         67,  70,  72,  77,  79,  83,  93, 101, 115, 117, 118, 122, 130,
#        141, 151, 153, 161, 182, 185, 202, 205, 211, 217, 220, 231, 232,
#        247, 324, 329, 349, 358, 374, 379, 388, 399, 437]),)
# (425, 35)
#      index  Age  Attrition  BusinessTravel  DailyRate  Department  \
# 0      823   29          1               1        490           1
# 1       28   44          1               2        477           1
# 2      464   37          1               2        799           1
# 3      179   38          1               2       1380           1
# 4       96   24          1               2       1353           2
# ..     ...  ...        ...             ...        ...         ...
# 420   1438   23          0               1        638           2
# 421   1442   29          0               2       1092           1
# 422   1444   56          0               2        310           1
# ...

# %%
MonthlyIncome_high=(q3.MonthlyIncome + (1.5 *iqr.MonthlyIncome))
MonthlyIncome_high

index=np.where(df['MonthlyIncome'] >MonthlyIncome_high)


df=df.drop(df.index[index])
print(df.shape)

df.reset_index()
# Out:
# (425, 35)
#      index  Age  Attrition  BusinessTravel  DailyRate  Department  \
# 0      823   29          1               1        490           1
# 1       28   44          1               2        477           1
# 2      464   37          1               2        799           1
# 3      179   38          1               2       1380           1
# 4       96   24          1               2       1353           2
# ..     ...  ...        ...             ...        ...         ...
# 420   1438   23          0               1        638           2
# 421   1442   29          0               2       1092           1
# 422   1444   56          0               2        310           1
# 423   1452   50          0               1        878           2
# 424   1461   50          0               2        410           2
#
#      DistanceFromHome  Education  EducationField  EmployeeCount  ...  \
# 0                  10          3               1              1  ...
# ...

# %%
TrainingTimesLastYear_high=(q3.TrainingTimesLastYear + (1.5 *iqr.TrainingTimesLastYear))
TrainingTimesLastYear_high

index=np.where(df['TrainingTimesLastYear'] >TrainingTimesLastYear_high)


df=df.drop(df.index[index])
print(df.shape)

df.reset_index()
# Out:
# (380, 35)
#      index  Age  Attrition  BusinessTravel  DailyRate  Department  \
# 0      823   29          1               1        490           1
# 1       28   44          1               2        477           1
# 2      464   37          1               2        799           1
# 3      179   38          1               2       1380           1
# 4       96   24          1               2       1353           2
# ..     ...  ...        ...             ...        ...         ...
# 375   1438   23          0               1        638           2
# 376   1442   29          0               2       1092           1
# 377   1444   56          0               2        310           1
# 378   1452   50          0               1        878           2
# 379   1461   50          0               2        410           2
#
#      DistanceFromHome  Education  EducationField  EmployeeCount  ...  \
# 0                  10          3               1              1  ...
# ...

# %%
YearsAtCompany_high=(q3.YearsAtCompany + (1.5 *iqr.YearsAtCompany))
YearsAtCompany_high

index=np.where(df['YearsAtCompany'] >YearsAtCompany_high)


df=df.drop(df.index[index])
print(df.shape)

df.reset_index()
# Out:
# (374, 35)
#      index  Age  Attrition  BusinessTravel  DailyRate  Department  \
# 0      823   29          1               1        490           1
# 1      464   37          1               2        799           1
# 2      179   38          1               2       1380           1
# 3       96   24          1               2       1353           2
# 4      550   23          1               2        650           1
# ..     ...  ...        ...             ...        ...         ...
# 369   1438   23          0               1        638           2
# 370   1442   29          0               2       1092           1
# 371   1444   56          0               2        310           1
# 372   1452   50          0               1        878           2
# 373   1461   50          0               2        410           2
#
#      DistanceFromHome  Education  EducationField  EmployeeCount  ...  \
# 0                  10          3               1              1  ...
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
YearsSinceLastPromotion_high=(q3.YearsSinceLastPromotion + (1.5 *iqr.YearsSinceLastPromotion))
YearsSinceLastPromotion_high

index=np.where(df['YearsSinceLastPromotion'] >YearsSinceLastPromotion_high)


df=df.drop(df.index[index])
print(df.shape)

df.reset_index()
# Out:
# (328, 35)
#      index  Age  Attrition  BusinessTravel  DailyRate  Department  \
# 0      823   29          1               1        490           1
# 1      464   37          1               2        799           1
# 2      179   38          1               2       1380           1
# 3       96   24          1               2       1353           2
# 4      550   23          1               2        650           1
# ..     ...  ...        ...             ...        ...         ...
# 323   1396   53          0               2       1168           2
# 324   1438   23          0               1        638           2
# 325   1442   29          0               2       1092           1
# 326   1452   50          0               1        878           2
# 327   1461   50          0               2        410           2
#
#      DistanceFromHome  Education  EducationField  EmployeeCount  ...  \
# 0                  10          3               1              1  ...
# ...

# %%
df.shape
# Out:
# (328, 35)

# %%
X=df.drop(['Attrition'],axis=1)
y=df['Attrition']

# %%
X.skew()
# Out:
# Age                         0.662145
# BusinessTravel             -1.403737
# DailyRate                   0.115838
# Department                  0.109465
# DistanceFromHome            0.717329
# Education                  -0.360766
# EducationField              0.554847
# EmployeeCount               0.000000
# EmployeeNumber              0.015832
# EnvironmentSatisfaction    -0.125779
# Gender                     -0.399722
# HourlyRate                  0.075469
# JobInvolvement             -0.561738
# JobLevel                    0.862259
# JobRole                    -0.419587
# JobSatisfaction            -0.134135
# MaritalStatus              -0.408325
# MonthlyIncome               1.298969
# MonthlyRate                 0.100338
# NumCompaniesWorked          0.932669
# Over18                      0.000000
# OverTime                    0.478570
# PercentSalaryHike           0.788239
# PerformanceRating           1.816953
# RelationshipSatisfaction   -0.116104
# ...

# %%
from sklearn.preprocessing import PowerTransformer

# %%
pt = PowerTransformer()

# %%
x_new=pt.fit_transform(X)

# %%
pd.DataFrame(x_new,columns=X.columns).skew()
# Out:
# Age                         0.000708
# BusinessTravel             -0.879298
# DailyRate                  -0.158504
# Department                  0.000150
# DistanceFromHome           -0.055405
# Education                  -0.121519
# EducationField             -0.012755
# EmployeeCount               0.000000
# EmployeeNumber             -0.315303
# EnvironmentSatisfaction    -0.155801
# Gender                     -0.399722
# HourlyRate                 -0.074663
# JobInvolvement             -0.056704
# JobLevel                    0.356254
# JobRole                    -0.359715
# JobSatisfaction            -0.151471
# MaritalStatus              -0.266579
# MonthlyIncome               0.000000
# MonthlyRate                -0.156168
# NumCompaniesWorked          0.026652
# Over18                      0.000000
# OverTime                    0.478570
# PercentSalaryHike           0.102151
# PerformanceRating           0.000000
# RelationshipSatisfaction   -0.141125
# ...

# %%
type(x_new)
# Out:
# numpy.ndarray

# %%
X=pd.DataFrame(x_new,columns=X.columns)

# %%
type(X)
# Out:
# pandas.core.frame.DataFrame

# %%
X.corrwith(y)
# Out:
# Age                         0.077861
# BusinessTravel              0.117381
# DailyRate                   0.052037
# Department                 -0.136697
# DistanceFromHome           -0.082747
# Education                   0.185595
# EducationField              0.011996
# EmployeeCount                    NaN
# EmployeeNumber             -0.096624
# EnvironmentSatisfaction     0.151587
# Gender                      0.075311
# HourlyRate                 -0.035604
# JobInvolvement              0.023798
# JobLevel                   -0.073581
# JobRole                    -0.047355
# JobSatisfaction            -0.108270
# MaritalStatus               0.038276
# MonthlyIncome                    NaN
# MonthlyRate                 0.075509
# NumCompaniesWorked         -0.022658
# Over18                           NaN
# OverTime                    0.042934
# PercentSalaryHike           0.013865
# PerformanceRating           0.110329
# RelationshipSatisfaction    0.123592
# ...

# %% [markdown]
# droppin Over18,StandardHours, performance rating and employee count as these columns have no relation with target value

# %%
X=X.drop(['EmployeeCount','Over18','PerformanceRating','StandardHours'],axis=1)

# %%
X.shape
# Out:
# (328, 30)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.metrics import accuracy_score,confusion_matrix, roc_curve,roc_auc_score

# %% [markdown]
# #LOGISTIC REGRESSION

# %%
lr=LogisticRegression()

# %%
for i in range(0,1000):
   x_train,x_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=i)
   lr.fit(x_train,y_train)
   pred_train=lr.predict(x_train)
   pred_test=lr.predict(x_test)
   if round(accuracy_score(y_train,pred_train)*100,1)==round(accuracy_score(y_test,pred_test)*100,1):
     print('At random state ',i,'performs well')
     print('At random state:-',i)
     print('Training accuracy score is:-',accuracy_score(y_train,pred_train)*100,1)
     print('Testing accuracy score is:-',accuracy_score(y_test,pred_test)*100,1)

# %%
x_train,x_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=870)

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test,pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.53      0.57      0.55        37
#            1       0.38      0.34      0.36        29
#
#     accuracy                           0.47        66
#    macro avg       0.45      0.46      0.45        66
# weighted avg       0.46      0.47      0.47        66

# %%
pred_lr=lr.predict(x_test)

from sklearn.model_selection import cross_val_score

lss=accuracy_score(y_test,pred_lr)

for j in range(2,10):
  lsscore=cross_val_score(lr,X,y,cv=j)
  lsc=lsscore.mean()

  print('At cv:-',j)
  print('Cross validation score is:-',lsc*100)
  print('Accuracy score :-',lss*100)
  print('\n')
# Out:
# At cv:- 2
# Cross validation score is:- 54.87804878048781
# Accuracy score :- 75.75757575757575
#
#
# At cv:- 3
# Cross validation score is:- 61.025854879065896
# Accuracy score :- 75.75757575757575
#
#
# At cv:- 4
# Cross validation score is:- 68.59756097560977
# Accuracy score :- 75.75757575757575
#
#
# At cv:- 5
# Cross validation score is:- 68.8997668997669
# Accuracy score :- 75.75757575757575
#
#
# At cv:- 6
# Cross validation score is:- 67.37934904601572
# Accuracy score :- 75.75757575757575
#
#
# At cv:- 7
# Cross validation score is:- 69.8163076516453
# Accuracy score :- 75.75757575757575
#
#
# At cv:- 8
# Cross validation score is:- 71.34146341463415
# Accuracy score :- 75.75757575757575
#
#
# At cv:- 9
# Cross validation score is:- 70.41207874541207
# Accuracy score :- 75.75757575757575

# %%
lsscore_selected=cross_val_score(lr,X,y,cv=8).mean()

print('The cv score is:',lsscore_selected,'\n The accuracy score is:',lss)
# Out:
# The cv score is: 0.7134146341463414
#  The accuracy score is: 0.7575757575757576

# %% [markdown]
# #Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt=DecisionTreeClassifier()

# %%
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
dt_train_pred=dt.predict(x_train)

# %%
dt_test_pred=dt.predict(x_test)

# %%
print(classification_report(y_train,dt_train_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       141
#            1       1.00      1.00      1.00       121
#
#     accuracy                           1.00       262
#    macro avg       1.00      1.00      1.00       262
# weighted avg       1.00      1.00      1.00       262

# %%
print(classification_report(y_test,dt_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.57      0.62      0.60        37
#            1       0.46      0.41      0.44        29
#
#     accuracy                           0.53        66
#    macro avg       0.52      0.52      0.52        66
# weighted avg       0.53      0.53      0.53        66

# %% [markdown]
# #Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf=RandomForestClassifier()

# %%
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
rf_train_pred=rf.predict(x_train)

# %%
rf_test_pred=rf.predict(x_test)

# %%
print(classification_report(y_train,rf_train_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       141
#            1       1.00      1.00      1.00       121
#
#     accuracy                           1.00       262
#    macro avg       1.00      1.00      1.00       262
# weighted avg       1.00      1.00      1.00       262

# %%
print(classification_report(y_test,rf_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.71      0.73      0.72        37
#            1       0.64      0.62      0.63        29
#
#     accuracy                           0.68        66
#    macro avg       0.68      0.68      0.68        66
# weighted avg       0.68      0.68      0.68        66

# %% [markdown]
# #Hyper Parameter Tuning

# %%
param_grid = [    
    {'penalty' : ['l1', 'l2', 'elasticnet', 'none'],
    'C' : np.logspace(-4, 4, 20),
    'solver' : ['lbfgs','newton-cg','liblinear','sag','saga'],
    'max_iter' : [100, 1000,2500, 5000]
    }
]

# %%
from sklearn.model_selection import GridSearchCV

# %%
grid_search=GridSearchCV(estimator=lr,
                        param_grid=param_grid ,
                        cv=8,
                        n_jobs= -1)

# %%
grid_search.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=8, estimator=LogisticRegression(), n_jobs=-1,
#              param_grid=[{'C': array([1.00000000e-04, 2.63665090e-04, 6.95192796e-04, 1.83298071e-03,
#        4.83293024e-03, 1.27427499e-02, 3.35981829e-02, 8.85866790e-02,
#        2.33572147e-01, 6.15848211e-01, 1.62377674e+00, 4.28133240e+00,
#        1.12883789e+01, 2.97635144e+01, 7.84759970e+01, 2.06913808e+02,
#        5.45559478e+02, 1.43844989e+03, 3.79269019e+03, 1.00000000e+04]),
#                           'max_iter': [100, 1000, 2500, 5000],
#                           'penalty': ['l1', 'l2', 'elasticnet', 'none'],
#                           'solver': ['lbfgs', 'newton-cg', 'liblinear', 'sag',
#                                      'saga']}])

# %%
best_parameters=grid_search.best_params_
print(best_parameters)
# Out:
# {'C': 0.03359818286283781, 'max_iter': 100, 'penalty': 'l2', 'solver': 'liblinear'}

# %%
lr=LogisticRegression(C=0.0335981828628378, max_iter = 100 , penalty='l2', solver='liblinear')

# %%
lr.fit(x_train,y_train)
# Out:
# LogisticRegression(C=0.0335981828628378, solver='liblinear')

# %%
lr_train_pred=lr.predict(x_train)

# %%
lr_test_pred=lr.predict(x_test)

# %%
print(classification_report(y_test,lr_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.71      0.81      0.76        37
#            1       0.71      0.59      0.64        29
#
#     accuracy                           0.71        66
#    macro avg       0.71      0.70      0.70        66
# weighted avg       0.71      0.71      0.71        66

# %% [markdown]
# #AUC & ROC curve

# %%
from sklearn.metrics import roc_curve,auc

# %%
from sklearn.metrics import plot_roc_curve

# %%
disp=plot_roc_curve(dt,x_test,y_test)

plot_roc_curve(lr,x_test,y_test,ax=disp.ax_)

plot_roc_curve(rf,x_test,y_test,ax=disp.ax_)


plt.legend(prop={'size':10},loc='lower right')

plt.show()

# %% [markdown]
# We will take logistic regression as our model as it has more accuracy than others
